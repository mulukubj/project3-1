# %% [markdown]
# # Prepare the workspace - load Keras, Tensorflow

# %%
from __future__ import print_function
import keras
from keras.utils import np_utils
from keras.utils.vis_utils import plot_model
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
import matplotlib.pyplot as plt

# %% [markdown]
# # Import the MNIST dataset + create variables for our test and training data

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %% [markdown]
# # CNN specific shape of the data

# %%
# input image dimensions of MNIST data
img_rows, img_cols = 28, 28
x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)

# %% [markdown]
# # Preprocess the data
# Note we do not shape it into a 1D vector of size 28*28 = 784 here, but rather keep the images as 28 x 28 x 1 to be used with 2D convolution layer.
#
# Compare this preprocessing steps in the code MNIST_HelloWorld_DLinR code!

# %%
# rescale
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (60000, 28, 28, 1)
# x_test shape: (10000, 28, 28, 1)
# 60000 train samples
# 10000 test samples

# %% [markdown]
# ## The y data is an integer vector with values ranging from 0 to 9.  To prepare this data for training we one-hot encode the vectors into binary class matrices

# %%
# One hot encoding
y_train = keras.utils.np_utils.to_categorical(y_train, 10) 
y_test = keras.utils.np_utils.to_categorical(y_test, 10)
print('y_train shape:', y_train.shape)
print('y_test shape:', y_test.shape)
# Out:
# y_train shape: (60000, 10)
# y_test shape: (10000, 10)

# %% [markdown]
# # Build the model
# Building the neural network requires configuring the layers of the model then compiling the model.
#
# # Setup the layers

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=(img_rows, img_cols, 1)))
#project 3 : Add the two layers should be added here to run the full code!
model.add(Conv2D(32, kernel_size=(3,3), activation='relu',input_shape=(img_rows, img_cols, 1)))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.4))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(10, activation='softmax'))

# %% [markdown]
# # Print the details of the model

# %%
#keras.utils.print_summary(model)
model.summary()
# You can also plot instead
keras.utils.vis_utils.plot_model(model)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 26, 26, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 32)        9248
#
#  max_pooling2d (MaxPooling2D  (None, 12, 12, 32)       0
#  )
#
#  dropout (Dropout)           (None, 12, 12, 32)        0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 128)               589952
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 10)                1290
#
# =================================================================
# Total params: 600,810
# Trainable params: 600,810
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Compile the model - define loss and optimizer

# %%
model.compile(
  loss= 'categorical_crossentropy',
  optimizer= 'adam',
  metrics='accuracy'
  )

# %% [markdown]
# # Train the model

# %%
history = model.fit(
  x_train, y_train,
  epochs=30, batch_size=128,
  validation_split=0.2
)
# Out:
# Epoch 1/30
# 375/375 [==============================] - 14s 7ms/step - loss: 0.2732 - accuracy: 0.9163 - val_loss: 0.0703 - val_accuracy: 0.9803
# Epoch 2/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0884 - accuracy: 0.9728 - val_loss: 0.0492 - val_accuracy: 0.9856
# Epoch 3/30
# 375/375 [==============================] - 3s 8ms/step - loss: 0.0654 - accuracy: 0.9792 - val_loss: 0.0455 - val_accuracy: 0.9862
# Epoch 4/30
# 375/375 [==============================] - 3s 9ms/step - loss: 0.0514 - accuracy: 0.9833 - val_loss: 0.0410 - val_accuracy: 0.9869
# Epoch 5/30
# 375/375 [==============================] - 2s 7ms/step - loss: 0.0444 - accuracy: 0.9859 - val_loss: 0.0397 - val_accuracy: 0.9881
# Epoch 6/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0356 - accuracy: 0.9881 - val_loss: 0.0403 - val_accuracy: 0.9883
# Epoch 7/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0341 - accuracy: 0.9888 - val_loss: 0.0349 - val_accuracy: 0.9899
# Epoch 8/30
# 375/375 [==============================] - 2s 7ms/step - loss: 0.0295 - accuracy: 0.9902 - val_loss: 0.0371 - val_accuracy: 0.9902
# Epoch 9/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0292 - accuracy: 0.9902 - val_loss: 0.0425 - val_accuracy: 0.9886
# Epoch 10/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0254 - accuracy: 0.9913 - val_loss: 0.0385 - val_accuracy: 0.9896
# Epoch 11/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0240 - accuracy: 0.9922 - val_loss: 0.0381 - val_accuracy: 0.9897
# Epoch 12/30
# 375/375 [==============================] - 2s 7ms/step - loss: 0.0209 - accuracy: 0.9933 - val_loss: 0.0382 - val_accuracy: 0.9897
# Epoch 13/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0201 - accuracy: 0.9931 - val_loss: 0.0370 - val_accuracy: 0.9902
# Epoch 14/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0207 - accuracy: 0.9932 - val_loss: 0.0395 - val_accuracy: 0.9893
# Epoch 15/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0183 - accuracy: 0.9940 - val_loss: 0.0399 - val_accuracy: 0.9892
# Epoch 16/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0183 - accuracy: 0.9942 - val_loss: 0.0348 - val_accuracy: 0.9908
# Epoch 17/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0173 - accuracy: 0.9943 - val_loss: 0.0321 - val_accuracy: 0.9913
# Epoch 18/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0159 - accuracy: 0.9946 - val_loss: 0.0350 - val_accuracy: 0.9911
# Epoch 19/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0163 - accuracy: 0.9943 - val_loss: 0.0359 - val_accuracy: 0.9912
# Epoch 20/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0143 - accuracy: 0.9955 - val_loss: 0.0360 - val_accuracy: 0.9906
# Epoch 21/30
# 375/375 [==============================] - 2s 7ms/step - loss: 0.0140 - accuracy: 0.9951 - val_loss: 0.0375 - val_accuracy: 0.9909
# Epoch 22/30
# 375/375 [==============================] - 2s 7ms/step - loss: 0.0125 - accuracy: 0.9955 - val_loss: 0.0337 - val_accuracy: 0.9918
# Epoch 23/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0121 - accuracy: 0.9957 - val_loss: 0.0401 - val_accuracy: 0.9910
# Epoch 24/30
# 375/375 [==============================] - 2s 7ms/step - loss: 0.0125 - accuracy: 0.9958 - val_loss: 0.0367 - val_accuracy: 0.9916
# Epoch 25/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0123 - accuracy: 0.9960 - val_loss: 0.0315 - val_accuracy: 0.9918
# Epoch 26/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0121 - accuracy: 0.9959 - val_loss: 0.0375 - val_accuracy: 0.9910
# Epoch 27/30
# 375/375 [==============================] - 2s 6ms/step - loss: 0.0111 - accuracy: 0.9959 - val_loss: 0.0386 - val_accuracy: 0.9916
# Epoch 28/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0113 - accuracy: 0.9960 - val_loss: 0.0374 - val_accuracy: 0.9914
# Epoch 29/30
# 375/375 [==============================] - 3s 7ms/step - loss: 0.0111 - accuracy: 0.9963 - val_loss: 0.0367 - val_accuracy: 0.9912
# Epoch 30/30
# 375/375 [==============================] - 2s 7ms/step - loss: 0.0099 - accuracy: 0.9965 - val_loss: 0.0411 - val_accuracy: 0.9909

# %% [markdown]
# ## The history object returned by fit() includes loss and accuracy metrics which we can plot

# %%
# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ### evaulating result

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.030174972489476204
# Test accuracy: 0.9926999807357788

# %% [markdown]
# # Project 3
# ## Add two layers after the initial convolutional layer in "Setup the layers" above
# 1. Convolutional layer with kernel size 3 x 3 with relu
# 2. Maxpool layer with size 2 x 2
# ### Submit the code chunk below
# It should be of the form:
#
# ---
# ```
# model = Sequential()
# model.add(Conv2D(32, kernel_size=(3, 3),
#                  activation='relu',
#                  input_shape=(img_rows, img_cols, 1)))
# model.add(Your convolutional layer here!)
# model.add(Your maxpool layer here!)
# model.add(Dropout(0.25))
# model.add(Flatten())
# model.add(Dense(128, activation='relu'))
# model.add(Dropout(0.5))
# model.add(Dense(10, activation='softmax'))
# ```
# ---
#
# ## Make sure you ran the full code with these two additional layers added, and report the final training accuracy value, test accuracy value.

# %%
# Enter your code chunk here
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=(img_rows, img_cols, 1)))
# model.add(Your convolutional layer here!)
# model.add(Your maxpool layer here!)
model.add(Dropout(0.4))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(10, activation='softmax'))
